# %% [markdown]
# # Experiment 1

# %% [markdown]
# In this experiment we are going to measure the efficiency tradeoffs between the LNET architecture and the AlexNet architecture on a simple vs a more complex dataset.
